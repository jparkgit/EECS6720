# %%
import pandas as pd

folder = '/Users/jihyunpark/Documents/Columbia/2026 Spring/Bayesian/HW2/data_csv'
X_set1 = pd.read_csv(os.path.join(folder, 'X_set1.csv'), header=None, usecols=lambda x: x != 0)
X_set2 = pd.read_csv(os.path.join(folder, 'X_set2.csv'), header=None, usecols=lambda x: x != 0)
X_set3 = pd.read_csv(os.path.join(folder, 'X_set3.csv'), header=None, usecols=lambda x: x != 0)
y_set1 = pd.read_csv(os.path.join(folder, 'y_set1.csv'), header=None)
y_set2 = pd.read_csv(os.path.join(folder, 'y_set2.csv'), header=None)
y_set3 = pd.read_csv(os.path.join(folder, 'y_set3.csv'), header=None)

# %%
print(X_set1.shape)
print(X_set2.shape)
print(X_set3.shape)
print(y_set1.shape)
print(y_set2.shape)
print(y_set3.shape)
# Out:
# (100, 100)
# (250, 250)
# (500, 500)
# (100, 1)
# (250, 1)
# (500, 1)

# %%
X_input = X_set1.values
y_input = y_set1.values.flatten()

print(f"X shape: {X_input.shape}") # Should be (N, d)
print(f"y shape: {y_input.shape}") # Should be (N,)
# Out:
# X shape: (100, 100)
# y shape: (100,)

# %%
z_set3 = pd.read_csv(os.path.join(folder, 'z_set3.csv'), header=None)
print(z_set3.shape)
# Out:
# (500, 1)
